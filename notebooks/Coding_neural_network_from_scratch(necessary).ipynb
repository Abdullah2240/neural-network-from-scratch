# %%
import numpy as np
import nnfs
from nnfs.datasets  import spiral_data
nnfs.init()

# %%
# Dense Layer
class DenseLayer:
    def __init__(self, n_inputs, n_neurons,
                 weight_regularization_l1=0., bias_regularization_l1=0.,
                 weight_regularization_l2=0., bias_regularization_l2=0.):
        # initializes the weights
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
        self.weight_regularization_l1 = weight_regularization_l1
        self.bias_regularization_l1 = bias_regularization_l1
        self.weight_regularization_l2 = weight_regularization_l2
        self.bias_regularization_l2 = bias_regularization_l2
        
    def forward(self, inputs):
        self.inputs = inputs
        self.outputs = np.dot(inputs, self.weights) + self.biases
        
    def backward(self, dvalues):
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dinputs = np.dot(dvalues, self.weights.T)
        self.dbiases = np.sum(dvalues, axis=0, keepdims=True)
                    
        # Changing weights and biases with respect to the regularization loss
        if self.weight_regularization_l1 > 0:
            dwL1 = np.ones_like(self.weights)
            dwL1[self.weights < 0] = -1
            self.dweights += self.weight_regularization_l1 * dwL1
        
        if self.bias_regularization_l1 > 0:
            dbL1 = np.ones_like(self.biases)
            dbL1[self.biases < 0] = -1
            self.dbiases += self.bias_regularization_l1 * dbL1
            
        if self.weight_regularization_l2 > 0:
            self.dweights += 2 * self.weight_regularization_l2 * self.weights

        if self.bias_regularization_l2 > 0:
            self.dbiases += 2 * self.bias_regularization_l2 * self.biases

# %%
# ReLU class

class Activation_ReLU:
    def forward(self, inputs):
        self.inputs = inputs
        self.outputs = np.maximum(0, inputs)
    def backward(self, dvalues):
        self.dinputs = dvalues.copy()
        self.dinputs[self.inputs <= 0] = 0

# %%
# Softmax activation

class Activation_Softmax:
    def forward(self, inputs):
        exp_inputs = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_inputs / np.sum(exp_inputs, axis=1, keepdims=True)
        self.outputs = probabilities

# %%
class Loss:

    def calculate(self, output, y):
        sample_losses = self.forward(output, y)
        data_loss = np.mean(sample_losses)
        return data_loss

    def regularization_loss(self, layer):
        regularization_loss = 0

        # L1 on weights
        if layer.weight_regularization_l1 > 0:
            regularization_loss += layer.weight_regularization_l1 * np.sum(np.abs(layer.weights))
        # L1 on biases
        if layer.bias_regularization_l1 > 0:
            regularization_loss += layer.bias_regularization_l1 * np.sum(np.abs(layer.biases))
        # L2 on weights
        if layer.weight_regularization_l2 > 0:
            regularization_loss += layer.weight_regularization_l2 * np.sum(layer.weights * layer.weights)
        # L2 on biases
        if layer.bias_regularization_l2 > 0:
            regularization_loss += layer.bias_regularization_l2 * np.sum(layer.biases * layer.biases)

        return regularization_loss

# %%
# Loss Function

class Loss_CategoricalCrossentropy(Loss):
    def forward(self, y_pred, y_true):
        y_pred_clipped = np.clip(y_pred, 1e-7, 1 - 1e-7)
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[range(len(y_pred)), y_true]
        elif len(y_true.shape) == 2: 
            correct_confidences = np.sum(y_true*y_pred_clipped, axis=1)
             
        negative_log_likelihoods = -np.log(correct_confidences)
        return negative_log_likelihoods

    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        labels = len(dvalues[0])
        if len(y_true.shape) == 1:
            # One Hot Encoding
            y_true = np.eye(labels)[y_true]
        self.dinputs = - y_true / dvalues
        # Normalization
        self.dinputs = self.dinputs / samples

# %%
# Softmax Classifier - combined with softax activation
# and cross-entropy loss for faster backward step

class Activation_Softmax_Loss_CategoricalCrossEntropy:
    def __init__(self):
        self.activation = Activation_Softmax()
        self.loss = Loss_CategoricalCrossentropy()

    def forward(self, inputs, y_true):
        self.activation.forward(inputs)
        self.outputs = self.activation.outputs

        return self.loss.calculate(self.outputs, y_true)

    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        if len(y_true.shape) == 2:
            # One Hot Encoding
            y_true = np.argmax(y_true, axis=1)
        self.dinputs = dvalues.copy()

        self.dinputs[range(samples), y_true] -= 1
        self.dinputs = self.dinputs / samples

# %%
class Optimizer_Adam:
    def __init__(self, learning_rate=0.001, decay=0., epsilon=1e-7, beta1=0.9, beta2=0.999):
        self.learning_rate = learning_rate
        # current learing rate is the one with alpha
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.epsilon = epsilon
        self.iterations = 0
        self.beta1 = beta1
        self.beta2 = beta2

    # Call once before updation
    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = self.learning_rate * (1. /( 1. + self.decay * self.iterations))
            
    def update_params(self, layer):
        if not hasattr(layer, "weight_cache"):
            layer.weight_momentums = np.zeros_like(layer.weights)
            layer.bias_momentums = np.zeros_like(layer.biases)
            layer.weight_cache = np.zeros_like(layer.weights)
            layer.bias_cache = np.zeros_like(layer.biases)

        layer.weight_cache = self.beta2 * layer.weight_cache + (1 - self.beta2) * (layer.dweights ** 2)
        layer.bias_cache   = self.beta2 * layer.bias_cache   + (1 - self.beta2) * (layer.dbiases ** 2)
        
        layer.weight_momentums = (self.beta1 * layer.weight_momentums) + ((1 - self.beta1) * layer.dweights)                                                                         
        layer.bias_momentums = (self.beta1 * layer.bias_momentums) + ((1 - self.beta1) * layer.dbiases)

        weight_momentums_updated = layer.weight_momentums / ((1 - self.beta1**(self.iterations+1)))
        bias_momentums_updated = layer.bias_momentums / ((1 - self.beta1**(self.iterations+1)))

        weight_cache_updated = layer.weight_cache / ((1 - self.beta2**(self.iterations+1)))
        bias_cache_updated = layer.bias_cache / ((1 - self.beta2**(self.iterations+1)))
        
        layer.weights += -self.current_learning_rate * \
                        weight_momentums_updated / \
                        (np.sqrt(weight_cache_updated) + self.epsilon)
        

        layer.biases += -self.current_learning_rate * \
                        bias_momentums_updated / \
                        (np.sqrt(bias_cache_updated) + self.epsilon)

    # Call once after updation
    def post_update_params(self):
        self.iterations += 1

# %%
class Layer_Dropout:
    def __init__(self, rate):
        self.rate = 1 - rate
    
    def forward(self, inputs):
        self.inputs = inputs
        self.binary_mask = np.random.binomial(1, self.rate, size=inputs.shape) / self.rate
        self.outputs = inputs * self.binary_mask
    
    def backward(self, dvalues):
        self.dinputs = dvalues * self.binary_mask

# %%
# Trying the whole thing with L1/L2 regularization and Dropout
X, y = spiral_data(classes=3, samples=1000)
# dense1 = DenseLayer(2, 64)
dense1 = DenseLayer(2, 64, weight_regularization_l2=5e-4, bias_regularization_l2=5e-4)
activation1 = Activation_ReLU()
dropout1 = Layer_Dropout(0.1)
dense2 = DenseLayer(64, 3)
loss_activation = Activation_Softmax_Loss_CategoricalCrossEntropy()
optimizer = Optimizer_Adam(learning_rate=0.05, decay=5e-5)

for epoch in range(10001):
    # Forward Pass
    dense1.forward(X)
    activation1.forward(dense1.outputs)
    dropout1.forward(activation1.outputs) # # change flow
    dense2.forward(dropout1.outputs)

    #Loss Calculation
    data_loss = loss_activation.forward(dense2.outputs, y)
    regularization_loss = (
        loss_activation.loss.regularization_loss(dense1) +
        loss_activation.loss.regularization_loss(dense2)       
    )

    loss = data_loss + regularization_loss

    predictions = np.argmax(loss_activation.outputs, axis=1)
    if len(y.shape) == 2:
        y = np.argmax(y, axis=1)
    acc = np.mean(predictions == y)

    if not epoch % 100:
        print(f'epoch: {epoch}, ' + 
              f'acc: {acc:.3f} ' + 
              f'data_loss: {loss:.3f} ' +
              f'regularization_loss: {regularization_loss:.3f} ' +
              f'total_loss: {loss:.3f} ' +
              f'lr: {optimizer.current_learning_rate:.8f}')
        
    # Back Pass
    loss_activation.backward(loss_activation.outputs, y)
    dense2.backward(loss_activation.dinputs)
    dropout1.backward(dense2.dinputs) # change flow
    activation1.backward(dropout1.dinputs)
    dense1.backward(activation1.dinputs)

    
    # Optimization
    optimizer.pre_update_params()
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    optimizer.post_update_params()

X_test, y_test = spiral_data(classes=3, samples=100)
dense1.forward(X_test)
activation1.forward(dense1.outputs)
dense2.forward(activation1.outputs)
loss = loss_activation.forward(dense2.outputs, y_test)

predictions = np.argmax(loss_activation.outputs, axis=1)
if len(y_test.shape) == 2:
    y_test = np.argmax(y_test, axis=1)
acc = np.mean(predictions == y_test)
print(f"evaluation, acc: {acc:.3f}, loss: {loss:3f}")
# Out:
# epoch: 0, acc: 0.360 data_loss: 1.099 regularization_loss: 0.000 total_loss: 1.099 lr: 0.05000000
# epoch: 100, acc: 0.608 data_loss: 0.872 regularization_loss: 0.032 total_loss: 0.872 lr: 0.04975372
# epoch: 200, acc: 0.658 data_loss: 0.814 regularization_loss: 0.038 total_loss: 0.814 lr: 0.04950740
# epoch: 300, acc: 0.641 data_loss: 0.811 regularization_loss: 0.038 total_loss: 0.811 lr: 0.04926351
# epoch: 400, acc: 0.656 data_loss: 0.805 regularization_loss: 0.037 total_loss: 0.805 lr: 0.04902201
# epoch: 500, acc: 0.669 data_loss: 0.767 regularization_loss: 0.038 total_loss: 0.767 lr: 0.04878287
# epoch: 600, acc: 0.670 data_loss: 0.755 regularization_loss: 0.037 total_loss: 0.755 lr: 0.04854605
# epoch: 700, acc: 0.661 data_loss: 0.752 regularization_loss: 0.036 total_loss: 0.752 lr: 0.04831151
# epoch: 800, acc: 0.678 data_loss: 0.759 regularization_loss: 0.034 total_loss: 0.759 lr: 0.04807923
# epoch: 900, acc: 0.651 data_loss: 0.764 regularization_loss: 0.034 total_loss: 0.764 lr: 0.04784918
# epoch: 1000, acc: 0.674 data_loss: 0.761 regularization_loss: 0.033 total_loss: 0.761 lr: 0.04762132
# epoch: 1100, acc: 0.669 data_loss: 0.740 regularization_loss: 0.032 total_loss: 0.740 lr: 0.04739561
# epoch: 1200, acc: 0.666 data_loss: 0.752 regularization_loss: 0.031 total_loss: 0.752 lr: 0.04717204
# epoch: 1300, acc: 0.681 data_loss: 0.740 regularization_loss: 0.031 total_loss: 0.740 lr: 0.04695056
# epoch: 1400, acc: 0.674 data_loss: 0.743 regularization_loss: 0.030 total_loss: 0.743 lr: 0.04673116
# epoch: 1500, acc: 0.674 data_loss: 0.727 regularization_loss: 0.030 total_loss: 0.727 lr: 0.04651379
# epoch: 1600, acc: 0.683 data_loss: 0.741 regularization_loss: 0.029 total_loss: 0.741 lr: 0.04629844
# epoch: 1700, acc: 0.676 data_loss: 0.729 regularization_loss: 0.029 total_loss: 0.729 lr: 0.04608507
# epoch: 1800, acc: 0.673 data_loss: 0.744 regularization_loss: 0.028 total_loss: 0.744 lr: 0.04587366
# epoch: 1900, acc: 0.669 data_loss: 0.727 regularization_loss: 0.028 total_loss: 0.727 lr: 0.04566419
# epoch: 2000, acc: 0.673 data_loss: 0.725 regularization_loss: 0.027 total_loss: 0.725 lr: 0.04545661
# epoch: 2100, acc: 0.656 data_loss: 0.744 regularization_loss: 0.027 total_loss: 0.744 lr: 0.04525092
# epoch: 2200, acc: 0.681 data_loss: 0.737 regularization_loss: 0.026 total_loss: 0.737 lr: 0.04504707
# epoch: 2300, acc: 0.691 data_loss: 0.729 regularization_loss: 0.026 total_loss: 0.729 lr: 0.04484506
# epoch: 2400, acc: 0.687 data_loss: 0.716 regularization_loss: 0.026 total_loss: 0.716 lr: 0.04464485
# epoch: 2500, acc: 0.684 data_loss: 0.713 regularization_loss: 0.026 total_loss: 0.713 lr: 0.04444642
# epoch: 2600, acc: 0.671 data_loss: 0.730 regularization_loss: 0.026 total_loss: 0.730 lr: 0.04424975
# epoch: 2700, acc: 0.677 data_loss: 0.753 regularization_loss: 0.026 total_loss: 0.753 lr: 0.04405480
# epoch: 2800, acc: 0.682 data_loss: 0.708 regularization_loss: 0.026 total_loss: 0.708 lr: 0.04386157
# epoch: 2900, acc: 0.665 data_loss: 0.713 regularization_loss: 0.026 total_loss: 0.713 lr: 0.04367003
# epoch: 3000, acc: 0.677 data_loss: 0.742 regularization_loss: 0.025 total_loss: 0.742 lr: 0.04348015
# epoch: 3100, acc: 0.690 data_loss: 0.724 regularization_loss: 0.025 total_loss: 0.724 lr: 0.04329192
# epoch: 3200, acc: 0.669 data_loss: 0.738 regularization_loss: 0.025 total_loss: 0.738 lr: 0.04310531
# epoch: 3300, acc: 0.693 data_loss: 0.709 regularization_loss: 0.025 total_loss: 0.709 lr: 0.04292030
# epoch: 3400, acc: 0.686 data_loss: 0.717 regularization_loss: 0.025 total_loss: 0.717 lr: 0.04273687
# epoch: 3500, acc: 0.682 data_loss: 0.744 regularization_loss: 0.025 total_loss: 0.744 lr: 0.04255500
# epoch: 3600, acc: 0.686 data_loss: 0.700 regularization_loss: 0.024 total_loss: 0.700 lr: 0.04237468
# epoch: 3700, acc: 0.679 data_loss: 0.729 regularization_loss: 0.024 total_loss: 0.729 lr: 0.04219587
# epoch: 3800, acc: 0.699 data_loss: 0.688 regularization_loss: 0.024 total_loss: 0.688 lr: 0.04201857
# epoch: 3900, acc: 0.692 data_loss: 0.724 regularization_loss: 0.024 total_loss: 0.724 lr: 0.04184275
# epoch: 4000, acc: 0.674 data_loss: 0.707 regularization_loss: 0.024 total_loss: 0.707 lr: 0.04166840
# epoch: 4100, acc: 0.700 data_loss: 0.699 regularization_loss: 0.023 total_loss: 0.699 lr: 0.04149550
# epoch: 4200, acc: 0.687 data_loss: 0.731 regularization_loss: 0.023 total_loss: 0.731 lr: 0.04132402
# epoch: 4300, acc: 0.697 data_loss: 0.695 regularization_loss: 0.023 total_loss: 0.695 lr: 0.04115396
# epoch: 4400, acc: 0.686 data_loss: 0.732 regularization_loss: 0.023 total_loss: 0.732 lr: 0.04098529
# epoch: 4500, acc: 0.684 data_loss: 0.724 regularization_loss: 0.023 total_loss: 0.724 lr: 0.04081799
# epoch: 4600, acc: 0.672 data_loss: 0.714 regularization_loss: 0.022 total_loss: 0.714 lr: 0.04065206
# epoch: 4700, acc: 0.690 data_loss: 0.700 regularization_loss: 0.022 total_loss: 0.700 lr: 0.04048747
# epoch: 4800, acc: 0.694 data_loss: 0.707 regularization_loss: 0.022 total_loss: 0.707 lr: 0.04032421
# epoch: 4900, acc: 0.695 data_loss: 0.706 regularization_loss: 0.022 total_loss: 0.706 lr: 0.04016226
# epoch: 5000, acc: 0.697 data_loss: 0.707 regularization_loss: 0.022 total_loss: 0.707 lr: 0.04000160
# epoch: 5100, acc: 0.702 data_loss: 0.699 regularization_loss: 0.022 total_loss: 0.699 lr: 0.03984222
# epoch: 5200, acc: 0.717 data_loss: 0.694 regularization_loss: 0.022 total_loss: 0.694 lr: 0.03968411
# epoch: 5300, acc: 0.685 data_loss: 0.720 regularization_loss: 0.022 total_loss: 0.720 lr: 0.03952725
# epoch: 5400, acc: 0.682 data_loss: 0.720 regularization_loss: 0.022 total_loss: 0.720 lr: 0.03937163
# epoch: 5500, acc: 0.691 data_loss: 0.720 regularization_loss: 0.022 total_loss: 0.720 lr: 0.03921722
# epoch: 5600, acc: 0.693 data_loss: 0.712 regularization_loss: 0.022 total_loss: 0.712 lr: 0.03906403
# epoch: 5700, acc: 0.687 data_loss: 0.705 regularization_loss: 0.022 total_loss: 0.705 lr: 0.03891202
# epoch: 5800, acc: 0.692 data_loss: 0.707 regularization_loss: 0.021 total_loss: 0.707 lr: 0.03876119
# epoch: 5900, acc: 0.685 data_loss: 0.720 regularization_loss: 0.021 total_loss: 0.720 lr: 0.03861153
# epoch: 6000, acc: 0.694 data_loss: 0.713 regularization_loss: 0.021 total_loss: 0.713 lr: 0.03846302
# epoch: 6100, acc: 0.707 data_loss: 0.691 regularization_loss: 0.021 total_loss: 0.691 lr: 0.03831564
# epoch: 6200, acc: 0.689 data_loss: 0.710 regularization_loss: 0.021 total_loss: 0.710 lr: 0.03816940
# epoch: 6300, acc: 0.690 data_loss: 0.733 regularization_loss: 0.021 total_loss: 0.733 lr: 0.03802426
# epoch: 6400, acc: 0.697 data_loss: 0.699 regularization_loss: 0.021 total_loss: 0.699 lr: 0.03788022
# epoch: 6500, acc: 0.681 data_loss: 0.703 regularization_loss: 0.021 total_loss: 0.703 lr: 0.03773727
# epoch: 6600, acc: 0.687 data_loss: 0.704 regularization_loss: 0.021 total_loss: 0.704 lr: 0.03759540
# epoch: 6700, acc: 0.696 data_loss: 0.696 regularization_loss: 0.021 total_loss: 0.696 lr: 0.03745459
# epoch: 6800, acc: 0.685 data_loss: 0.693 regularization_loss: 0.020 total_loss: 0.693 lr: 0.03731483
# epoch: 6900, acc: 0.688 data_loss: 0.719 regularization_loss: 0.020 total_loss: 0.719 lr: 0.03717610
# epoch: 7000, acc: 0.675 data_loss: 0.715 regularization_loss: 0.020 total_loss: 0.715 lr: 0.03703841
# epoch: 7100, acc: 0.694 data_loss: 0.698 regularization_loss: 0.020 total_loss: 0.698 lr: 0.03690173
# epoch: 7200, acc: 0.699 data_loss: 0.691 regularization_loss: 0.020 total_loss: 0.691 lr: 0.03676606
# epoch: 7300, acc: 0.691 data_loss: 0.714 regularization_loss: 0.020 total_loss: 0.714 lr: 0.03663138
# epoch: 7400, acc: 0.694 data_loss: 0.723 regularization_loss: 0.020 total_loss: 0.723 lr: 0.03649768
# epoch: 7500, acc: 0.687 data_loss: 0.718 regularization_loss: 0.020 total_loss: 0.718 lr: 0.03636496
# epoch: 7600, acc: 0.681 data_loss: 0.738 regularization_loss: 0.020 total_loss: 0.738 lr: 0.03623320
# epoch: 7700, acc: 0.697 data_loss: 0.738 regularization_loss: 0.020 total_loss: 0.738 lr: 0.03610239
# epoch: 7800, acc: 0.694 data_loss: 0.709 regularization_loss: 0.020 total_loss: 0.709 lr: 0.03597252
# epoch: 7900, acc: 0.694 data_loss: 0.710 regularization_loss: 0.020 total_loss: 0.710 lr: 0.03584358
# epoch: 8000, acc: 0.689 data_loss: 0.694 regularization_loss: 0.020 total_loss: 0.694 lr: 0.03571556
# epoch: 8100, acc: 0.675 data_loss: 0.709 regularization_loss: 0.020 total_loss: 0.709 lr: 0.03558846
# epoch: 8200, acc: 0.682 data_loss: 0.692 regularization_loss: 0.019 total_loss: 0.692 lr: 0.03546225
# epoch: 8300, acc: 0.703 data_loss: 0.701 regularization_loss: 0.020 total_loss: 0.701 lr: 0.03533694
# epoch: 8400, acc: 0.688 data_loss: 0.705 regularization_loss: 0.020 total_loss: 0.705 lr: 0.03521251
# epoch: 8500, acc: 0.698 data_loss: 0.705 regularization_loss: 0.020 total_loss: 0.705 lr: 0.03508895
# epoch: 8600, acc: 0.697 data_loss: 0.697 regularization_loss: 0.020 total_loss: 0.697 lr: 0.03496626
# epoch: 8700, acc: 0.684 data_loss: 0.721 regularization_loss: 0.020 total_loss: 0.721 lr: 0.03484442
# epoch: 8800, acc: 0.704 data_loss: 0.689 regularization_loss: 0.020 total_loss: 0.689 lr: 0.03472343
# epoch: 8900, acc: 0.685 data_loss: 0.712 regularization_loss: 0.020 total_loss: 0.712 lr: 0.03460327
# epoch: 9000, acc: 0.684 data_loss: 0.698 regularization_loss: 0.020 total_loss: 0.698 lr: 0.03448395
# epoch: 9100, acc: 0.704 data_loss: 0.711 regularization_loss: 0.020 total_loss: 0.711 lr: 0.03436544
# epoch: 9200, acc: 0.700 data_loss: 0.689 regularization_loss: 0.020 total_loss: 0.689 lr: 0.03424775
# epoch: 9300, acc: 0.685 data_loss: 0.693 regularization_loss: 0.020 total_loss: 0.693 lr: 0.03413086
# epoch: 9400, acc: 0.703 data_loss: 0.698 regularization_loss: 0.020 total_loss: 0.698 lr: 0.03401476
# epoch: 9500, acc: 0.677 data_loss: 0.694 regularization_loss: 0.020 total_loss: 0.694 lr: 0.03389945
# epoch: 9600, acc: 0.702 data_loss: 0.720 regularization_loss: 0.020 total_loss: 0.720 lr: 0.03378493
# epoch: 9700, acc: 0.703 data_loss: 0.714 regularization_loss: 0.020 total_loss: 0.714 lr: 0.03367117
# epoch: 9800, acc: 0.706 data_loss: 0.685 regularization_loss: 0.020 total_loss: 0.685 lr: 0.03355817
# epoch: 9900, acc: 0.703 data_loss: 0.694 regularization_loss: 0.020 total_loss: 0.694 lr: 0.03344593
# epoch: 10000, acc: 0.690 data_loss: 0.695 regularization_loss: 0.019 total_loss: 0.695 lr: 0.03333444
# evaluation, acc: 0.733, loss: 0.585371
